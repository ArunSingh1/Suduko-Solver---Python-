# %% [markdown]
# # Suduko code solver with recursion with Brute force

# %% [raw]
# Our Objective is solve a suduko 9x9 puzzle using python 3.6
#
# Standard Sudoku contains 81 cells, in a 9×9 grid, and has 9 boxes, each box being the intersection of the first, middle, or last 3 rows, and the first, middle, or last 3 columns.
#
# Each Square must have all the values from 1 to 9
# Each Row in 9x9 grid must have all the values from 1 to 9
# Each column in 9x9 grid must have all the values from 1 to 9
# A Number cannot appear more than once in a row, column and in square
#
# Pseudo Code:
#
# First - Fill all the "Obvious" cells with values untill we ran out
#         if puzzed is Solved (run Solve()) return True
#         if we encountered contradiction return False
#
# Second -Find the First Empty cell and get all the Possibilities at that cell
#
# Third   -For every possibility at a cell
#             fill the possibility at a cell and Run Solve()
#             if true return true
#             if return false, undo the previous changes and loop again with next possibility untill the condition becomes true
#          return false (if All the possibilities are wrong then there is something wrong intially at the obvious or the given              sudoku is invalid

# %% [raw]
# lets dive into the recursive alogrithm,
#
# The input is fed into the code as a list of strings
# board = [
#     "9.5.28..7",
#     ".7...35.6",
#     ".4.5.....",
#     "7..8...5.",
#     "8...1...3",
#     ".6...5..2",
#     ".....9.3.",
#     "5.61...8.",
#     "3..78.1.5"
# ]
# here each row will be converted into a separate list as shown below:

# %%
board = [
    "9.5.28..7",
    ".7...35.6",
    ".4.5.....",
    "7..8...5.",
    "8...1...3",
    ".6...5..2",
    ".....9.3.",
    "5.61...8.",
    "3..78.1.5"
]

def main():
    global board
    for idx,line in enumerate(board):
        board[idx] = list(line)
        print(list(line))
main()
# Out:
# ['9', '.', '5', '.', '2', '8', '.', '.', '7']
# ['.', '7', '.', '.', '.', '3', '5', '.', '6']
# ['.', '4', '.', '5', '.', '.', '.', '.', '.']
# ['7', '.', '.', '8', '.', '.', '.', '5', '.']
# ['8', '.', '.', '.', '1', '.', '.', '.', '3']
# ['.', '6', '.', '.', '.', '5', '.', '.', '2']
# ['.', '.', '.', '.', '.', '9', '.', '3', '.']
# ['5', '.', '6', '1', '.', '.', '.', '8', '.']
# ['3', '.', '.', '7', '8', '.', '1', '.', '5']

# %% [raw]
# Solve()
# this function is working the house of this code, it creates a list of possibilities by getPossibilities() function, this function iterates through row and columns as i and j
# if the lenght of the possibilities become 1 then the cell should upadte that possibilty
#
# 			if len(possibilities) == 1:
# 				board[i,j] = possibilities[0]
#
# getPossibilities(i,j)
# This function checks which values are possible at a particular cell as indicated by “i” and “j”. By starting off with a set, this function works by taking away values it encounters while looping through the row “i” and column “j”, in addition to the square associated with (i,j). The result is cast to a list and returned
#
# possibilities = {str(n) for n in range(1,10)}
#  ie.
# possibilities = {'4', '3', '8', '6', '9', '5', '2', '7', '1'} SET IS INHERENTLY ORDERLESS
#
# getPossibilities(i,j) iterates through board values
#
#     for val in board[i]:
# 		possibilities = possibilities - set(val)
#
#     for idx in range(0,9):
# 		possibilities = possibilities - set(board[idx][j])
#
# possibilities gets subtracted from the values which are already present in the grid, thus getting actual possible outcomes for rows columns and sqaure girds
#
# Iterating through Squaregrids
#
# 	iStart = (i // 3) * 3
# 	jStart = (i // 3) * 3
#
#
# iStart & jStart is used to find the location in grid
#
# 	subboard = board[iStart:iStart+3]
# 	for idx, row in enumerate(subboard):   ######   slicling the rows in sqaure
# 		subboard[idx]= row[jStart:jStart+3]   ######     slicling the columns in sqaure
#
# 	for row in subboard:
# 		for col in row:
# 			possibilities = possibilities - set(col)
#
#
# here we can find the possible outcomes for empty cell (2,2) in given board

# %%
board = [
	".........",
	"5.3.67...",
	"9..3421..",
	".....4...",
	"..1...72.",
	"..2.1....",
	".3......9",
	".8.1..2..",
	"...75.8.6"
]

def main():
	global board
	for idx, line in enumerate(board):
		#print(idx, line) list os string
		board[idx] =list(line)
		#print(list(line)) # list of list 


	#solve()
	print(getPossibilities(2,2))

def solve():
	global board
	for i in range(0,10):  #to loop through rows and columns 
		for j in range(0,10):
			possibilities = getPossibilities(i,j)
			if possibilities == False:
				continue
			if len(possibilities) == 1:            #if the possibilties has came to only one then the cell should upadte that possibilty
				board[i,j] = possibilities[0]

def getPossibilities(i,j):
	global board
	if board[i][j] != "." :	   # if cell is filled, not empty "." it returns false
		return False

	possibilities = {str(n) for n in range(1,10)}

	for val in board[i]:
		possibilities = possibilities - set(val)

	for idx in range(0,9):
		possibilities = possibilities - set(board[idx][j])
 
	iStart = (i // 3) * 3     
	jStart = (i // 3) * 3

	subboard = board[iStart:iStart+3]
	for idx, row in enumerate(subboard):   #slicling the rows in sqaure
		subboard[idx]= row[jStart:jStart+3]   #slicling the columns in sqaure

	for row in subboard:
		for col in row:
			possibilities = possibilities - set(col)

	return list(possibilities)

main()
# Out:
# ['7', '6', '8']

# %%
import copy

board = [
    "9.5.28..7",
    ".7...35.6",
    ".4.5.....",
    "7..8...5.",
    "8...1...3",
    ".6...5..2",
    ".....9.3.",
    "5.61...8.",
    "3..78.1.5"
]

def main():
    global board
    for idx,line in enumerate(board):
        board[idx] = list(line)
        
    solve()
    printBoard()
    
       
def solve():
    global board
    
    try:
        fillAllObvious()
    except:
        return False
    
    if isComplete():
        return True
    
    i,j = 0,0
    for rowIdx,row in enumerate(board):
        for colIdx,col in enumerate(row):
            if col == ".":
                i,j = rowIdx, colIdx
                
    possibilities = getPossibilities(i,j)
    for value in possibilities:
        snapshot = copy.deepcopy(board)
    
        board[i][j] = value
        result = solve()
        if result == True:
            return True
        else:
            board = copy.deepcopy(snapshot)
            
    return False

def fillAllObvious():
    global board
    while True:
        somethingChanged = False
        for i in range(0,9):
            for j in range(0,9):
                possibilities = getPossibilities(i,j)
                if possibilities == False:
                    continue
                if len(possibilities) == 0:
                    raise RuntimeError("No moves left")
                if len(possibilities) == 1:
                    board[i][j] = possibilities[0]
                    somethingChanged = True
                    
        if somethingChanged == False:
            return
                
def getPossibilities(i,j):
    global board
    if board[i][j] != ".":
        return False
        
    possibilities = {str(n) for n in range(1,10)}
    
    for val in board[i]:
        possibilities -= set(val)
        
    for idx in range(0,9):
        possibilities -= set( board[idx][j] )
        
    iStart = (i // 3) * 3
    jStart = (j // 3) * 3
    
    subboard = board[iStart:iStart+3]
    for idx,row in enumerate(subboard):
        subboard[idx] = row[jStart:jStart+3]
    
    for row in subboard:
        for col in row:
            possibilities -= set(col)
            
    return list(possibilities)

def printBoard():
    global board
    for row in board:
        for col in row:
            print(col, end="")
        print("")
        
def isComplete():
    for row in board:
        for col in row:
            if (col == "."):
                return False
                
    return True
    
main()
# Out:
# 915628347
# 278943516
# 643571298
# 739862451
# 852417963
# 461395872
# 187259634
# 526134789
# 394786125
